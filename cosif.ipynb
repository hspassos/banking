# %%
import requests
import os
from datetime import datetime, date
from dateutil.relativedelta import relativedelta # Para adicionar meses facilmente

def baixar_dados_bcb_mes_a_mes(
    ano_inicio=2010,
    mes_inicio=1,
    tipo_dado="BANCOS",
    diretorio_destino="dados_bcb_cosif"
):
    """
    Baixa dados do Banco Central mês a mês, usando um padrão de URL.

    Args:
        ano_inicio (int): Ano de início para o download.
        mes_inicio (int): Mês de início para o download.
        tipo_dado (str): Sufixo no nome do arquivo (ex: "BANCOS").
        diretorio_destino (str): O diretório onde os arquivos serão salvos.
    """
    base_url = "https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/{}/"

    # Cria o diretório de destino se ele não existir
    if not os.path.exists(diretorio_destino):
        os.makedirs(diretorio_destino)
        print(f"Diretório '{diretorio_destino}' criado.")
    else:
        print(f"Diretório '{diretorio_destino}' já existe.")

    data_atual = date.today()
    data_iteracao = date(ano_inicio, mes_inicio, 1)

    print(f"Iniciando download dos dados de {mes_inicio:02d}/{ano_inicio} até {data_atual.month:02d}/{data_atual.year}...")

    # Loop pelos meses
    while data_iteracao <= data_atual:
        ano = data_iteracao.year
        mes = data_iteracao.month

        # Formata o mês e ano para o URL
        mes_str = f"{mes:02d}" # Garante dois dígitos (ex: 01, 02)
        ano_mes_str = f"{ano}{mes_str}"

        # Monta a URL completa do arquivo
        # Ex: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Bancos/202503BANCOS.zip
        download_url = base_url.format(tipo_dado) + f"{ano_mes_str}{tipo_dado}.zip"
        
        # Define o nome do arquivo local
        nome_arquivo = f"{ano_mes_str}{tipo_dado}.csv.zip"
        caminho_completo_arquivo = os.path.join(diretorio_destino, nome_arquivo)

        print(f"Tentando baixar: {nome_arquivo}")

        if os.path.exists(caminho_completo_arquivo):
            print(f"  Arquivo '{nome_arquivo}' já existe. Pulando.")
        else:
            try:
                response = requests.get(download_url, stream=True)
                response.raise_for_status() # Levanta um erro para códigos de status HTTP ruins (4xx ou 5xx)

                with open(caminho_completo_arquivo, 'wb') as f:
                    for chunk in response.iter_content(chunk_size=8192):
                        f.write(chunk)
                print(f"  Download concluído: {nome_arquivo}")
            except requests.exceptions.RequestException as e:
                print(f"  Erro ao baixar {nome_arquivo}: {e}")
                print(f"  URL tentada: {download_url}")
                # Se um arquivo não existir, não é necessariamente um erro fatal, pode ser que o BCB
                # não o tenha disponibilizado para aquele mês/ano.

        # Avança para o próximo mês
        data_iteracao += relativedelta(months=1)

# --- Configurações de Download ---
ANO_INICIO_DOWNLOAD = 2010
MES_INICIO_DOWNLOAD = 1 # Janeiro

# O sufixo que identifica o tipo de dado na URL e no nome do arquivo.
# Pelo seu exemplo, "Bancos" é para Balancetes de Bancos.
# Se houver outros tipos de dados com padrões semelhantes,
# você pode chamar a função novamente com um tipo_dado diferente.
TIPO_DADO_PARA_BAIXAR = "Bancos"

# Chama a função para iniciar o download
baixar_dados_bcb_mes_a_mes(
    ano_inicio=ANO_INICIO_DOWNLOAD,
    mes_inicio=MES_INICIO_DOWNLOAD,
    tipo_dado=TIPO_DADO_PARA_BAIXAR
)

print("\nProcesso de download concluído.")
# Out:
# Diretório 'dados_bcb_cosif' já existe.
# Iniciando download dos dados de 01/2010 até 07/2025...
#   Download concluído: 202106Bancos.csv.zip
# Tentando baixar: 202107Bancos.csv.zip
#   Download concluído: 202107Bancos.csv.zip
# Tentando baixar: 202108Bancos.csv.zip
#   Download concluído: 202108Bancos.csv.zip
# Tentando baixar: 202109Bancos.csv.zip
#   Download concluído: 202109Bancos.csv.zip
# Tentando baixar: 202110Bancos.csv.zip
#   Download concluído: 202110Bancos.csv.zip
# Tentando baixar: 202111Bancos.csv.zip
#   Download concluído: 202111Bancos.csv.zip
# Tentando baixar: 202112Bancos.csv.zip
#   Download concluído: 202112Bancos.csv.zip
# Tentando baixar: 202201Bancos.csv.zip
#   Download concluído: 202201Bancos.csv.zip
# Tentando baixar: 202202Bancos.csv.zip
#   Download concluído: 202202Bancos.csv.zip
# Tentando baixar: 202203Bancos.csv.zip
#   Download concluído: 202203Bancos.csv.zip
# Tentando baixar: 202204Bancos.csv.zip
#   Download concluído: 202204Bancos.csv.zip
# Tentando baixar: 202205Bancos.csv.zip
#   Download concluído: 202205Bancos.csv.zip
# Tentando baixar: 202206Bancos.csv.zip
#   Download concluído: 202206Bancos.csv.zip
# Tentando baixar: 202207Bancos.csv.zip
#   Download concluído: 202207Bancos.csv.zip
# Tentando baixar: 202208Bancos.csv.zip
#   Download concluído: 202208Bancos.csv.zip
# Tentando baixar: 202209Bancos.csv.zip
#   Download concluído: 202209Bancos.csv.zip
# Tentando baixar: 202210Bancos.csv.zip
#   Download concluído: 202210Bancos.csv.zip
# Tentando baixar: 202211Bancos.csv.zip
#   Download concluído: 202211Bancos.csv.zip
# Tentando baixar: 202212Bancos.csv.zip
#   Erro ao baixar 202212Bancos.csv.zip: 404 Client Error: Not Found for url: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Bancos/202212Bancos.zip
#   URL tentada: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Bancos/202212Bancos.zip
# Tentando baixar: 202301Bancos.csv.zip
#   Erro ao baixar 202301Bancos.csv.zip: 404 Client Error: Not Found for url: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Bancos/202301Bancos.zip
#   URL tentada: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Bancos/202301Bancos.zip
# Tentando baixar: 202302Bancos.csv.zip
#   Arquivo '202302Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202303Bancos.csv.zip
#   Arquivo '202303Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202304Bancos.csv.zip
#   Arquivo '202304Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202305Bancos.csv.zip
#   Arquivo '202305Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202306Bancos.csv.zip
#   Arquivo '202306Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202307Bancos.csv.zip
#   Arquivo '202307Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202308Bancos.csv.zip
#   Arquivo '202308Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202309Bancos.csv.zip
#   Arquivo '202309Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202310Bancos.csv.zip
#   Arquivo '202310Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202311Bancos.csv.zip
#   Arquivo '202311Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202312Bancos.csv.zip
#   Arquivo '202312Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202401Bancos.csv.zip
#   Arquivo '202401Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202402Bancos.csv.zip
#   Arquivo '202402Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202403Bancos.csv.zip
#   Arquivo '202403Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202404Bancos.csv.zip
#   Arquivo '202404Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202405Bancos.csv.zip
#   Arquivo '202405Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202406Bancos.csv.zip
#   Arquivo '202406Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202407Bancos.csv.zip
#   Arquivo '202407Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202408Bancos.csv.zip
#   Arquivo '202408Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202409Bancos.csv.zip
#   Arquivo '202409Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202410Bancos.csv.zip
#   Arquivo '202410Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202411Bancos.csv.zip
#   Arquivo '202411Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202412Bancos.csv.zip
#   Arquivo '202412Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202501Bancos.csv.zip
#   Arquivo '202501Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202502Bancos.csv.zip
#   Arquivo '202502Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202503Bancos.csv.zip
#   Arquivo '202503Bancos.csv.zip' já existe. Pulando.
# Tentando baixar: 202504Bancos.csv.zip
#   Erro ao baixar 202504Bancos.csv.zip: 404 Client Error: Not Found for url: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Bancos/202504Bancos.zip
#   URL tentada: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Bancos/202504Bancos.zip
# Tentando baixar: 202505Bancos.csv.zip
#   Erro ao baixar 202505Bancos.csv.zip: 404 Client Error: Not Found for url: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Bancos/202505Bancos.zip
#   URL tentada: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Bancos/202505Bancos.zip
# Tentando baixar: 202506Bancos.csv.zip
#   Erro ao baixar 202506Bancos.csv.zip: 404 Client Error: Not Found for url: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Bancos/202506Bancos.zip
#   URL tentada: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Bancos/202506Bancos.zip
# Tentando baixar: 202507Bancos.csv.zip
#   Erro ao baixar 202507Bancos.csv.zip: 404 Client Error: Not Found for url: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Bancos/202507Bancos.zip
#   URL tentada: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Bancos/202507Bancos.zip
#
# Processo de download concluído.

# %%
import zipfile
import os

diretorio_zips="dados_bcb_cosif"
diretorio_destino_extraidos="dados_bancos"

arquivos_no_diretorio = os.listdir("dados_bcb_cosif")
zips_encontrados = [f for f in arquivos_no_diretorio if f.endswith('.zip')]

for i, nome_zip in enumerate(zips_encontrados):
    caminho_completo_zip = os.path.join("dados_bcb_cosif", nome_zip)
    
    try:
        with zipfile.ZipFile(caminho_completo_zip, 'r') as zip_ref:
            # Extrai todo o conteúdo do zip para o diretório de destino
            zip_ref.extractall(diretorio_destino_extraidos)
            print(f"  Extraído '{nome_zip}' ({i+1}/{len(zips_encontrados)}) para '{diretorio_destino_extraidos}'.")
    except zipfile.BadZipFile:
        print(f"  Erro: '{nome_zip}' não é um arquivo zip válido ou está corrompido. Pulando.")
    except Exception as e:
        print(f"  Erro inesperado ao extrair '{nome_zip}': {e}. Pulando.")
# Out:
#   Extraído '202411Bancos.csv.zip' (1/181) para 'dados_bancos'.
#   Extraído '202002Bancos.csv.zip' (2/181) para 'dados_bancos'.
#   Extraído '201601Bancos.csv.zip' (3/181) para 'dados_bancos'.
#   Extraído '201001Bancos.csv.zip' (4/181) para 'dados_bancos'.
#   Extraído '202109Bancos.csv.zip' (5/181) para 'dados_bancos'.
#   Extraído '202201Bancos.csv.zip' (6/181) para 'dados_bancos'.
#   Extraído '202503Bancos.csv.zip' (7/181) para 'dados_bancos'.
#   Extraído '201908Bancos.csv.zip' (8/181) para 'dados_bancos'.
#   Extraído '201010Bancos.csv.zip' (9/181) para 'dados_bancos'.
#   Extraído '201611Bancos.csv.zip' (10/181) para 'dados_bancos'.
#   Extraído '201705Bancos.csv.zip' (11/181) para 'dados_bancos'.
#   Extraído '201701Bancos.csv.zip' (12/181) para 'dados_bancos'.
#   Extraído '202207Bancos.csv.zip' (13/181) para 'dados_bancos'.
#   Extraído '202312Bancos.csv.zip' (14/181) para 'dados_bancos'.
#   Extraído '201612Bancos.csv.zip' (15/181) para 'dados_bancos'.
#   Extraído '201012Bancos.csv.zip' (16/181) para 'dados_bancos'.
#   Extraído '201405Bancos.csv.zip' (17/181) para 'dados_bancos'.
#   Extraído '201907Bancos.csv.zip' (18/181) para 'dados_bancos'.
#   Extraído '202003Bancos.csv.zip' (19/181) para 'dados_bancos'.
#   Extraído '201207Bancos.csv.zip' (20/181) para 'dados_bancos'.
#   Extraído '201409Bancos.csv.zip' (21/181) para 'dados_bancos'.
#   Extraído '201805Bancos.csv.zip' (22/181) para 'dados_bancos'.
#   Extraído '201806Bancos.csv.zip' (23/181) para 'dados_bancos'.
#   Extraído '201002Bancos.csv.zip' (24/181) para 'dados_bancos'.
#   Extraído '202412Bancos.csv.zip' (25/181) para 'dados_bancos'.
#   Extraído '201412Bancos.csv.zip' (26/181) para 'dados_bancos'.
#   Extraído '202403Bancos.csv.zip' (27/181) para 'dados_bancos'.
#   Extraído '201305Bancos.csv.zip' (28/181) para 'dados_bancos'.
#   Extraído '201804Bancos.csv.zip' (29/181) para 'dados_bancos'.
#   Extraído '201812Bancos.csv.zip' (30/181) para 'dados_bancos'.
#   Extraído '201312Bancos.csv.zip' (31/181) para 'dados_bancos'.
#   Extraído '201203Bancos.csv.zip' (32/181) para 'dados_bancos'.
#   Extraído '201407Bancos.csv.zip' (33/181) para 'dados_bancos'.
#   Extraído '201608Bancos.csv.zip' (34/181) para 'dados_bancos'.
#   Extraído '201803Bancos.csv.zip' (35/181) para 'dados_bancos'.
#   Extraído '202308Bancos.csv.zip' (36/181) para 'dados_bancos'.
#   Extraído '201011Bancos.csv.zip' (37/181) para 'dados_bancos'.
#   Extraído '202005Bancos.csv.zip' (38/181) para 'dados_bancos'.
#   Extraído '202012Bancos.csv.zip' (39/181) para 'dados_bancos'.
#   Extraído '202107Bancos.csv.zip' (40/181) para 'dados_bancos'.
#   Extraído '202405Bancos.csv.zip' (41/181) para 'dados_bancos'.
#   Extraído '201607Bancos.csv.zip' (42/181) para 'dados_bancos'.
#   Extraído '201402Bancos.csv.zip' (43/181) para 'dados_bancos'.
#   Extraído '201311Bancos.csv.zip' (44/181) para 'dados_bancos'.
#   Extraído '201005Bancos.csv.zip' (45/181) para 'dados_bancos'.
#   Extraído '202108Bancos.csv.zip' (46/181) para 'dados_bancos'.
#   Extraído '201903Bancos.csv.zip' (47/181) para 'dados_bancos'.
#   Extraído '201310Bancos.csv.zip' (48/181) para 'dados_bancos'.
#   Extraído '201009Bancos.csv.zip' (49/181) para 'dados_bancos'.
#   Extraído '202407Bancos.csv.zip' (50/181) para 'dados_bancos'.
#   Extraído '201003Bancos.csv.zip' (51/181) para 'dados_bancos'.
#   Extraído '201108Bancos.csv.zip' (52/181) para 'dados_bancos'.
#   Extraído '201408Bancos.csv.zip' (53/181) para 'dados_bancos'.
#   Extraído '201511Bancos.csv.zip' (54/181) para 'dados_bancos'.
#   Extraído '201209Bancos.csv.zip' (55/181) para 'dados_bancos'.
#   Extraído '201406Bancos.csv.zip' (56/181) para 'dados_bancos'.
#   Extraído '202008Bancos.csv.zip' (57/181) para 'dados_bancos'.
#   Extraído '202304Bancos.csv.zip' (58/181) para 'dados_bancos'.
#   Extraído '202307Bancos.csv.zip' (59/181) para 'dados_bancos'.
#   Extraído '202104Bancos.csv.zip' (60/181) para 'dados_bancos'.
#   Extraído '201508Bancos.csv.zip' (61/181) para 'dados_bancos'.
#   Extraído '201512Bancos.csv.zip' (62/181) para 'dados_bancos'.
#   Extraído '202009Bancos.csv.zip' (63/181) para 'dados_bancos'.
#   Extraído '201403Bancos.csv.zip' (64/181) para 'dados_bancos'.
#   Extraído '201105Bancos.csv.zip' (65/181) para 'dados_bancos'.
#   Extraído '201502Bancos.csv.zip' (66/181) para 'dados_bancos'.
#   Extraído '201609Bancos.csv.zip' (67/181) para 'dados_bancos'.
#   Extraído '201112Bancos.csv.zip' (68/181) para 'dados_bancos'.
#   Extraído '202103Bancos.csv.zip' (69/181) para 'dados_bancos'.
#   Extraído '201503Bancos.csv.zip' (70/181) para 'dados_bancos'.
#   Extraído '201307Bancos.csv.zip' (71/181) para 'dados_bancos'.
#   Extraído '201103Bancos.csv.zip' (72/181) para 'dados_bancos'.
#   Extraído '201411Bancos.csv.zip' (73/181) para 'dados_bancos'.
#   Extraído '201809Bancos.csv.zip' (74/181) para 'dados_bancos'.
#   Extraído '201110Bancos.csv.zip' (75/181) para 'dados_bancos'.
#   Extraído '201703Bancos.csv.zip' (76/181) para 'dados_bancos'.
#   Extraído '202206Bancos.csv.zip' (77/181) para 'dados_bancos'.
#   Extraído '201911Bancos.csv.zip' (78/181) para 'dados_bancos'.
#   Extraído '201909Bancos.csv.zip' (79/181) para 'dados_bancos'.
#   Extraído '201711Bancos.csv.zip' (80/181) para 'dados_bancos'.
#   Extraído '201102Bancos.csv.zip' (81/181) para 'dados_bancos'.
#   Extraído '201802Bancos.csv.zip' (82/181) para 'dados_bancos'.
#   Extraído '201712Bancos.csv.zip' (83/181) para 'dados_bancos'.
#   Extraído '201308Bancos.csv.zip' (84/181) para 'dados_bancos'.
#   Extraído '202004Bancos.csv.zip' (85/181) para 'dados_bancos'.
#   Extraído '201201Bancos.csv.zip' (86/181) para 'dados_bancos'.
#   Extraído '201810Bancos.csv.zip' (87/181) para 'dados_bancos'.
#   Extraído '202102Bancos.csv.zip' (88/181) para 'dados_bancos'.
#   Extraído '201109Bancos.csv.zip' (89/181) para 'dados_bancos'.
#   Extraído '202410Bancos.csv.zip' (90/181) para 'dados_bancos'.
#   Extraído '201606Bancos.csv.zip' (91/181) para 'dados_bancos'.
#   Extraído '201104Bancos.csv.zip' (92/181) para 'dados_bancos'.
#   Extraído '202101Bancos.csv.zip' (93/181) para 'dados_bancos'.
#   Extraído '202401Bancos.csv.zip' (94/181) para 'dados_bancos'.
#   Extraído '201904Bancos.csv.zip' (95/181) para 'dados_bancos'.
#   Extraído '201509Bancos.csv.zip' (96/181) para 'dados_bancos'.
#   Extraído '201808Bancos.csv.zip' (97/181) para 'dados_bancos'.
#   Extraído '202106Bancos.csv.zip' (98/181) para 'dados_bancos'.
#   Extraído '201211Bancos.csv.zip' (99/181) para 'dados_bancos'.
#   Extraído '201008Bancos.csv.zip' (100/181) para 'dados_bancos'.
#   Extraído '201602Bancos.csv.zip' (101/181) para 'dados_bancos'.
#   Extraído '202204Bancos.csv.zip' (102/181) para 'dados_bancos'.
#   Extraído '201704Bancos.csv.zip' (103/181) para 'dados_bancos'.
#   Extraído '201702Bancos.csv.zip' (104/181) para 'dados_bancos'.
#   Extraído '202112Bancos.csv.zip' (105/181) para 'dados_bancos'.
#   Extraído '202202Bancos.csv.zip' (106/181) para 'dados_bancos'.
#   Extraído '201303Bancos.csv.zip' (107/181) para 'dados_bancos'.
#   Extraído '202406Bancos.csv.zip' (108/181) para 'dados_bancos'.
#   Extraído '202408Bancos.csv.zip' (109/181) para 'dados_bancos'.
#   Extraído '202110Bancos.csv.zip' (110/181) para 'dados_bancos'.
#   Extraído '202105Bancos.csv.zip' (111/181) para 'dados_bancos'.
#   Extraído '201506Bancos.csv.zip' (112/181) para 'dados_bancos'.
#   Extraído '201205Bancos.csv.zip' (113/181) para 'dados_bancos'.
#   Extraído '202502Bancos.csv.zip' (114/181) para 'dados_bancos'.
#   Extraído '202409Bancos.csv.zip' (115/181) para 'dados_bancos'.
#   Extraído '201101Bancos.csv.zip' (116/181) para 'dados_bancos'.
#   Extraído '202404Bancos.csv.zip' (117/181) para 'dados_bancos'.
#   Extraído '201504Bancos.csv.zip' (118/181) para 'dados_bancos'.
#   Extraído '201306Bancos.csv.zip' (119/181) para 'dados_bancos'.
#   Extraído '201106Bancos.csv.zip' (120/181) para 'dados_bancos'.
#   Extraído '201501Bancos.csv.zip' (121/181) para 'dados_bancos'.
#   Extraído '201309Bancos.csv.zip' (122/181) para 'dados_bancos'.
#   Extraído '201304Bancos.csv.zip' (123/181) para 'dados_bancos'.
#   Extraído '201709Bancos.csv.zip' (124/181) para 'dados_bancos'.
#   Extraído '202402Bancos.csv.zip' (125/181) para 'dados_bancos'.
#   Extraído '202007Bancos.csv.zip' (126/181) para 'dados_bancos'.
#   Extraído '202211Bancos.csv.zip' (127/181) para 'dados_bancos'.
#   Extraído '201202Bancos.csv.zip' (128/181) para 'dados_bancos'.
#   Extraído '201007Bancos.csv.zip' (129/181) para 'dados_bancos'.
#   Extraído '201710Bancos.csv.zip' (130/181) para 'dados_bancos'.
#   Extraído '201301Bancos.csv.zip' (131/181) para 'dados_bancos'.
#   Extraído '201706Bancos.csv.zip' (132/181) para 'dados_bancos'.
#   Extraído '201210Bancos.csv.zip' (133/181) para 'dados_bancos'.
#   Extraído '202010Bancos.csv.zip' (134/181) para 'dados_bancos'.
#   Extraído '202306Bancos.csv.zip' (135/181) para 'dados_bancos'.
#   Extraído '202203Bancos.csv.zip' (136/181) para 'dados_bancos'.
#   Extraído '201302Bancos.csv.zip' (137/181) para 'dados_bancos'.
#   Extraído '201404Bancos.csv.zip' (138/181) para 'dados_bancos'.
#   Extraído '201505Bancos.csv.zip' (139/181) para 'dados_bancos'.
#   Extraído '201902Bancos.csv.zip' (140/181) para 'dados_bancos'.
#   Extraído '201510Bancos.csv.zip' (141/181) para 'dados_bancos'.
#   Extraído '201610Bancos.csv.zip' (142/181) para 'dados_bancos'.
#   Extraído '201605Bancos.csv.zip' (143/181) para 'dados_bancos'.
#   Extraído '201603Bancos.csv.zip' (144/181) para 'dados_bancos'.
#   Extraído '202208Bancos.csv.zip' (145/181) para 'dados_bancos'.
#   Extraído '202310Bancos.csv.zip' (146/181) para 'dados_bancos'.
#   Extraído '202205Bancos.csv.zip' (147/181) para 'dados_bancos'.
#   Extraído '201811Bancos.csv.zip' (148/181) para 'dados_bancos'.
#   Extraído '201906Bancos.csv.zip' (149/181) para 'dados_bancos'.
#   Extraído '202001Bancos.csv.zip' (150/181) para 'dados_bancos'.
#   Extraído '202209Bancos.csv.zip' (151/181) para 'dados_bancos'.
#   Extraído '201004Bancos.csv.zip' (152/181) para 'dados_bancos'.
#   Extraído '201604Bancos.csv.zip' (153/181) para 'dados_bancos'.
#   Extraído '201410Bancos.csv.zip' (154/181) para 'dados_bancos'.
#   Extraído '201905Bancos.csv.zip' (155/181) para 'dados_bancos'.
#   Extraído '201910Bancos.csv.zip' (156/181) para 'dados_bancos'.
#   Extraído '201912Bancos.csv.zip' (157/181) para 'dados_bancos'.
#   Extraído '201708Bancos.csv.zip' (158/181) para 'dados_bancos'.
#   Extraído '202309Bancos.csv.zip' (159/181) para 'dados_bancos'.
#   Extraído '201801Bancos.csv.zip' (160/181) para 'dados_bancos'.
#   Extraído '202302Bancos.csv.zip' (161/181) para 'dados_bancos'.
#   Extraído '202305Bancos.csv.zip' (162/181) para 'dados_bancos'.
#   Extraído '202006Bancos.csv.zip' (163/181) para 'dados_bancos'.
#   Extraído '202210Bancos.csv.zip' (164/181) para 'dados_bancos'.
#   Extraído '201901Bancos.csv.zip' (165/181) para 'dados_bancos'.
#   Extraído '201006Bancos.csv.zip' (166/181) para 'dados_bancos'.
#   Extraído '202011Bancos.csv.zip' (167/181) para 'dados_bancos'.
#   Extraído '201107Bancos.csv.zip' (168/181) para 'dados_bancos'.
#   Extraído '201707Bancos.csv.zip' (169/181) para 'dados_bancos'.
#   Extraído '201212Bancos.csv.zip' (170/181) para 'dados_bancos'.
#   Extraído '201807Bancos.csv.zip' (171/181) para 'dados_bancos'.
#   Extraído '201206Bancos.csv.zip' (172/181) para 'dados_bancos'.
#   Extraído '202311Bancos.csv.zip' (173/181) para 'dados_bancos'.
#   Extraído '202501Bancos.csv.zip' (174/181) para 'dados_bancos'.
#   Extraído '201111Bancos.csv.zip' (175/181) para 'dados_bancos'.
#   Extraído '201507Bancos.csv.zip' (176/181) para 'dados_bancos'.
#   Extraído '201208Bancos.csv.zip' (177/181) para 'dados_bancos'.
#   Extraído '202303Bancos.csv.zip' (178/181) para 'dados_bancos'.
#   Extraído '201401Bancos.csv.zip' (179/181) para 'dados_bancos'.
#   Extraído '201204Bancos.csv.zip' (180/181) para 'dados_bancos'.
#   Extraído '202111Bancos.csv.zip' (181/181) para 'dados_bancos'.

# %%
def baixar_dados_bcb_mes_a_mes(
    ano_inicio=2010,
    mes_inicio=1,
    tipo_dado="Sociedades",
    diretorio_destino="dados_bcb_cosif_sociedades"
):
    """
    Baixa dados do Banco Central mês a mês, usando um padrão de URL.

    Args:
        ano_inicio (int): Ano de início para o download.
        mes_inicio (int): Mês de início para o download.
        tipo_dado (str): Sufixo no nome do arquivo (ex: "BANCOS").
        diretorio_destino (str): O diretório onde os arquivos serão salvos.
    """
    base_url = "https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/{}/"

    # Cria o diretório de destino se ele não existir
    if not os.path.exists(diretorio_destino):
        os.makedirs(diretorio_destino)
        print(f"Diretório '{diretorio_destino}' criado.")
    else:
        print(f"Diretório '{diretorio_destino}' já existe.")

    data_atual = date.today()
    data_iteracao = date(ano_inicio, mes_inicio, 1)

    print(f"Iniciando download dos dados de {mes_inicio:02d}/{ano_inicio} até {data_atual.month:02d}/{data_atual.year}...")

    # Loop pelos meses
    while data_iteracao <= data_atual:
        ano = data_iteracao.year
        mes = data_iteracao.month

        # Formata o mês e ano para o URL
        mes_str = f"{mes:02d}" # Garante dois dígitos (ex: 01, 02)
        ano_mes_str = f"{ano}{mes_str}"

        # Monta a URL completa do arquivo
        # Ex: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Bancos/202503BANCOS.zip
        download_url = base_url.format(tipo_dado) + f"{ano_mes_str}{tipo_dado}.csv.zip"
        
        # Define o nome do arquivo local
        nome_arquivo = f"{ano_mes_str}{tipo_dado}.zip"
        caminho_completo_arquivo = os.path.join(diretorio_destino, nome_arquivo)

        print(f"Tentando baixar: {nome_arquivo}")

        if os.path.exists(caminho_completo_arquivo):
            print(f"  Arquivo '{nome_arquivo}' já existe. Pulando.")
        else:
            try:
                response = requests.get(download_url, stream=True)
                response.raise_for_status() # Levanta um erro para códigos de status HTTP ruins (4xx ou 5xx)

                with open(caminho_completo_arquivo, 'wb') as f:
                    for chunk in response.iter_content(chunk_size=8192):
                        f.write(chunk)
                print(f"  Download concluído: {nome_arquivo}")
            except requests.exceptions.RequestException as e:
                print(f"  Erro ao baixar {nome_arquivo}: {e}")
                print(f"  URL tentada: {download_url}")
                # Se um arquivo não existir, não é necessariamente um erro fatal, pode ser que o BCB
                # não o tenha disponibilizado para aquele mês/ano.

        # Avança para o próximo mês
        data_iteracao += relativedelta(months=1)

# --- Configurações de Download ---
ANO_INICIO_DOWNLOAD = 2010
MES_INICIO_DOWNLOAD = 1 # Janeiro

# O sufixo que identifica o tipo de dado na URL e no nome do arquivo.
# Pelo seu exemplo, "Bancos" é para Balancetes de Bancos.
# Se houver outros tipos de dados com padrões semelhantes,
# você pode chamar a função novamente com um tipo_dado diferente.
TIPO_DADO_PARA_BAIXAR = "Sociedades"

# Chama a função para iniciar o download
baixar_dados_bcb_mes_a_mes(
    ano_inicio=ANO_INICIO_DOWNLOAD,
    mes_inicio=MES_INICIO_DOWNLOAD,
    tipo_dado=TIPO_DADO_PARA_BAIXAR
)

print("\nProcesso de download concluído.")
# Out:
# Diretório 'dados_bcb_cosif_sociedades' já existe.
# Iniciando download dos dados de 01/2010 até 07/2025...
# Tentando baixar: 201001Sociedades.zip
#   Arquivo '201001Sociedades.zip' já existe. Pulando.
# Tentando baixar: 201002Sociedades.zip
#   Arquivo '201002Sociedades.zip' já existe. Pulando.
# Tentando baixar: 201003Sociedades.zip
#   Arquivo '201003Sociedades.zip' já existe. Pulando.
# Tentando baixar: 201004Sociedades.zip
#   Arquivo '201004Sociedades.zip' já existe. Pulando.
# Tentando baixar: 201005Sociedades.zip
#   Arquivo '201005Sociedades.zip' já existe. Pulando.
# Tentando baixar: 201006Sociedades.zip
#   Arquivo '201006Sociedades.zip' já existe. Pulando.
# Tentando baixar: 201007Sociedades.zip
#   Arquivo '201007Sociedades.zip' já existe. Pulando.
# Tentando baixar: 201008Sociedades.zip
#   Arquivo '201008Sociedades.zip' já existe. Pulando.
# Tentando baixar: 201009Sociedades.zip
#   Arquivo '201009Sociedades.zip' já existe. Pulando.
# Tentando baixar: 201010Sociedades.zip
#   Arquivo '201010Sociedades.zip' já existe. Pulando.
# Tentando baixar: 201011Sociedades.zip
#   Arquivo '201011Sociedades.zip' já existe. Pulando.
# Tentando baixar: 201012Sociedades.zip
#   Arquivo '201012Sociedades.zip' já existe. Pulando.
# Tentando baixar: 201101Sociedades.zip
#   Arquivo '201101Sociedades.zip' já existe. Pulando.
# Tentando baixar: 
zip: 404 Client Error: Not Found for url: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Sociedades/202506Sociedades.csv.zip
#   URL tentada: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Sociedades/202506Sociedades.csv.zip
# Tentando baixar: 202507Sociedades.zip
#   Erro ao baixar 202507Sociedades.zip: 404 Client Error: Not Found for url: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Sociedades/202507Sociedades.csv.zip
#   URL tentada: https://www.bcb.gov.br/content/estabilidadefinanceira/cosif/Sociedades/202507Sociedades.csv.zip
#
# Processo de download concluído.

# %%
import zipfile
import os

diretorio_zips="dados_bcb_cosif_sociedades"
diretorio_destino_extraidos="dados_sociedades"

arquivos_no_diretorio = os.listdir("dados_bcb_cosif_sociedades")
zips_encontrados = [f for f in arquivos_no_diretorio if f.endswith('.zip')]

for i, nome_zip in enumerate(zips_encontrados):
    caminho_completo_zip = os.path.join("dados_bcb_cosif_sociedades", nome_zip)
    
    try:
        with zipfile.ZipFile(caminho_completo_zip, 'r') as zip_ref:
            # Extrai todo o conteúdo do zip para o diretório de destino
            zip_ref.extractall(diretorio_destino_extraidos)
            print(f"  Extraído '{nome_zip}' ({i+1}/{len(zips_encontrados)}) para '{diretorio_destino_extraidos}'.")
    except zipfile.BadZipFile:
        print(f"  Erro: '{nome_zip}' não é um arquivo zip válido ou está corrompido. Pulando.")
    except Exception as e:
        print(f"  Erro inesperado ao extrair '{nome_zip}': {e}. Pulando.")

DIRETORIO_DOS_ZIPS = "dados_bcb_cosif_sociedades"

DIRETORIO_DOS_EXTRAIDOS = "dados_sociedades"
# Out:
#   Extraído '201512Sociedades.zip' (1/182) para 'dados_sociedades'.
#   Extraído '202203Sociedades.zip' (2/182) para 'dados_sociedades'.
#   Extraído '201906Sociedades.zip' (3/182) para 'dados_sociedades'.
#   Extraído '202003Sociedades.zip' (4/182) para 'dados_sociedades'.
#   Extraído '201401Sociedades.zip' (5/182) para 'dados_sociedades'.
#   Extraído '201111Sociedades.zip' (6/182) para 'dados_sociedades'.
#   Extraído '201209Sociedades.zip' (7/182) para 'dados_sociedades'.
#   Extraído '201212Sociedades.zip' (8/182) para 'dados_sociedades'.
#   Extraído '202102Sociedades.zip' (9/182) para 'dados_sociedades'.
#   Extraído '202103Sociedades.zip' (10/182) para 'dados_sociedades'.
#   Extraído '201403Sociedades.zip' (11/182) para 'dados_sociedades'.
#   Extraído '201005Sociedades.zip' (12/182) para 'dados_sociedades'.
#   Extraído '201502Sociedades.zip' (13/182) para 'dados_sociedades'.
#   Extraído '202112Sociedades.zip' (14/182) para 'dados_sociedades'.
#   Extraído '201503Sociedades.zip' (15/182) para 'dados_sociedades'.
#   Extraído '201201Sociedades.zip' (16/182) para 'dados_sociedades'.
#   Extraído '201806Sociedades.zip' (17/182) para 'dados_sociedades'.
#   Extraído '201406Sociedades.zip' (18/182) para 'dados_sociedades'.
#   Extraído '201611Sociedades.zip' (19/182) para 'dados_sociedades'.
#   Extraído '201011Sociedades.zip' (20/182) para 'dados_sociedades'.
#   Extraído '201903Sociedades.zip' (21/182) para 'dados_sociedades'.
#   Extraído '202407Sociedades.zip' (22/182) para 'dados_sociedades'.
#   Extraído '202502Sociedades.zip' (23/182) para 'dados_sociedades'.
#   Extraído '202307Sociedades.zip' (24/182) para 'dados_sociedades'.
#   Extraído '201106Sociedades.zip' (25/182) para 'dados_sociedades'.
#   Extraído '202404Sociedades.zip' (26/182) para 'dados_sociedades'.
#   Extraído '201203Sociedades.zip' (27/182) para 'dados_sociedades'.
#   Extraído '201102Sociedades.zip' (28/182) para 'dados_sociedades'.
#   Extraído '202302SOCIEDADES.csv.zip' (29/182) para 'dados_sociedades'.
#   Extraído '201210Sociedades.zip' (30/182) para 'dados_sociedades'.
#   Extraído '201305Sociedades.zip' (31/182) para 'dados_sociedades'.
#   Extraído '201712Sociedades.zip' (32/182) para 'dados_sociedades'.
#   Extraído '201501Sociedades.zip' (33/182) para 'dados_sociedades'.
#   Extraído '201606Sociedades.zip' (34/182) para 'dados_sociedades'.
#   Extraído '201710Sociedades.zip' (35/182) para 'dados_sociedades'.
#   Extraído '201707Sociedades.zip' (36/182) para 'dados_sociedades'.
#   Extraído '201008Sociedades.zip' (37/182) para 'dados_sociedades'.
#   Extraído '201108Sociedades.zip' (38/182) para 'dados_sociedades'.
#   Extraído '201409Sociedades.zip' (39/182) para 'dados_sociedades'.
#   Extraído '201709Sociedades.zip' (40/182) para 'dados_sociedades'.
#   Extraído '202105Sociedades.zip' (41/182) para 'dados_sociedades'.
#   Extraído '202405Sociedades.zip' (42/182) para 'dados_sociedades'.
#   Extraído '202106Sociedades.zip' (43/182) para 'dados_sociedades'.
#   Extraído '201206Sociedades.zip' (44/182) para 'dados_sociedades'.
#   Extraído '201905Sociedades.zip' (45/182) para 'dados_sociedades'.
#   Extraído '202107Sociedades.zip' (46/182) para 'dados_sociedades'.
#   Extraído '201407Sociedades.zip' (47/182) para 'dados_sociedades'.
#   Extraído '201307Sociedades.zip' (48/182) para 'dados_sociedades'.
#   Extraído '201604Sociedades.zip' (49/182) para 'dados_sociedades'.
#   Extraído '201310Sociedades.zip' (50/182) para 'dados_sociedades'.
#   Extraído '201908Sociedades.zip' (51/182) para 'dados_sociedades'.
#   Extraído '202312Sociedades.zip' (52/182) para 'dados_sociedades'.
#   Extraído '201109Sociedades.zip' (53/182) para 'dados_sociedades'.
#   Extraído '201112Sociedades.zip' (54/182) para 'dados_sociedades'.
#   Extraído '202006Sociedades.zip' (55/182) para 'dados_sociedades'.
#   Extraído '201205Sociedades.zip' (56/182) para 'dados_sociedades'.
#   Extraído '201704Sociedades.zip' (57/182) para 'dados_sociedades'.
#   Extraído '202002Sociedades.zip' (58/182) para 'dados_sociedades'.
#   Extraído '201602Sociedades.zip' (59/182) para 'dados_sociedades'.
#   Extraído '201302Sociedades.zip' (60/182) para 'dados_sociedades'.
#   Extraído '201811Sociedades.zip' (61/182) para 'dados_sociedades'.
#   Extraído '201803Sociedades.zip' (62/182) para 'dados_sociedades'.
#   Extraído '202304Sociedades.zip' (63/182) para 'dados_sociedades'.
#   Extraído '202503Sociedades.zip' (64/182) para 'dados_sociedades'.
#   Extraído '201701Sociedades.zip' (65/182) para 'dados_sociedades'.
#   Extraído '201410Sociedades.zip' (66/182) para 'dados_sociedades'.
#   Extraído '201804Sociedades.zip' (67/182) para 'dados_sociedades'.
#   Extraído '202201Sociedades.zip' (68/182) para 'dados_sociedades'.
#   Extraído '201405Sociedades.zip' (69/182) para 'dados_sociedades'.
#   Extraído '201706Sociedades.zip' (70/182) para 'dados_sociedades'.
#   Extraído '202207Sociedades.zip' (71/182) para 'dados_sociedades'.
#   Extraído '202411Sociedades.zip' (72/182) para 'dados_sociedades'.
#   Extraído '202206Sociedades.zip' (73/182) para 'dados_sociedades'.
#   Extraído '201809Sociedades.zip' (74/182) para 'dados_sociedades'.
#   Extraído '202309Sociedades.zip' (75/182) para 'dados_sociedades'.
#   Extraído '201705Sociedades.zip' (76/182) para 'dados_sociedades'.
#   Extraído '201204Sociedades.zip' (77/182) para 'dados_sociedades'.
#   Extraído '201304Sociedades.zip' (78/182) para 'dados_sociedades'.
#   Extraído '201511Sociedades.zip' (79/182) para 'dados_sociedades'.
#   Extraído '202011Sociedades.zip' (80/182) para 'dados_sociedades'.
#   Extraído '201003Sociedades.zip' (81/182) para 'dados_sociedades'.
#   Extraído '202007Sociedades.zip' (82/182) para 'dados_sociedades'.
#   Extraído '201608Sociedades.zip' (83/182) para 'dados_sociedades'.
#   Extraído '202104Sociedades.zip' (84/182) para 'dados_sociedades'.
#   Extraído '202108Sociedades.zip' (85/182) para 'dados_sociedades'.
#   Extraído '201708Sociedades.zip' (86/182) para 'dados_sociedades'.
#   Extraído '202008Sociedades.zip' (87/182) para 'dados_sociedades'.
#   Extraído '201101Sociedades.zip' (88/182) para 'dados_sociedades'.
#   Extraído '201609Sociedades.zip' (89/182) para 'dados_sociedades'.
#   Extraído '202109Sociedades.zip' (90/182) para 'dados_sociedades'.
#   Extraído '201505Sociedades.zip' (91/182) para 'dados_sociedades'.
#   Extraído '202308Sociedades.zip' (92/182) para 'dados_sociedades'.
#   Extraído '201601Sociedades.zip' (93/182) para 'dados_sociedades'.
#   Extraído '202202Sociedades.zip' (94/182) para 'dados_sociedades'.
#   Extraído '202001Sociedades.zip' (95/182) para 'dados_sociedades'.
#   Extraído '202409Sociedades.zip' (96/182) para 'dados_sociedades'.
#   Extraído '202410Sociedades.zip' (97/182) para 'dados_sociedades'.
#   Extraído '201802Sociedades.zip' (98/182) para 'dados_sociedades'.
#   Extraído '201007Sociedades.zip' (99/182) para 'dados_sociedades'.
#   Extraído '201506Sociedades.zip' (100/182) para 'dados_sociedades'.
#   Extraído '201408Sociedades.zip' (101/182) para 'dados_sociedades'.
#   Extraído '202210Sociedades.zip' (102/182) para 'dados_sociedades'.
#   Extraído '201207Sociedades.zip' (103/182) para 'dados_sociedades'.
#   Extraído '202004Sociedades.zip' (104/182) para 'dados_sociedades'.
#   Extraído '202403Sociedades.zip' (105/182) para 'dados_sociedades'.
#   Extraído '201911Sociedades.zip' (106/182) para 'dados_sociedades'.
#   Extraído '201308Sociedades.zip' (107/182) para 'dados_sociedades'.
#   Extraído '201202Sociedades.zip' (108/182) para 'dados_sociedades'.
#   Extraído '201907Sociedades.zip' (109/182) para 'dados_sociedades'.
#   Extraído '202408Sociedades.zip' (110/182) para 'dados_sociedades'.
#   Extraído '201504Sociedades.zip' (111/182) para 'dados_sociedades'.
#   Extraído '201303Sociedades.zip' (112/182) para 'dados_sociedades'.
#   Extraído '202110Sociedades.zip' (113/182) para 'dados_sociedades'.
#   Extraído '202305Sociedades.zip' (114/182) para 'dados_sociedades'.
#   Extraído '202306Sociedades.zip' (115/182) para 'dados_sociedades'.
#   Extraído '202010Sociedades.zip' (116/182) para 'dados_sociedades'.
#   Extraído '201912Sociedades.zip' (117/182) para 'dados_sociedades'.
#   Extraído '202205Sociedades.zip' (118/182) para 'dados_sociedades'.
#   Extraído '201402Sociedades.zip' (119/182) para 'dados_sociedades'.
#   Extraído '201001Sociedades.zip' (120/182) para 'dados_sociedades'.
#   Extraído '201004Sociedades.zip' (121/182) para 'dados_sociedades'.
#   Extraído '201610Sociedades.zip' (122/182) para 'dados_sociedades'.
#   Extraído '202302Sociedades.zip' (123/182) para 'dados_sociedades'.
#   Extraído '201412Sociedades.zip' (124/182) para 'dados_sociedades'.
#   Extraído '201010Sociedades.zip' (125/182) para 'dados_sociedades'.
#   Extraído '201301Sociedades.zip' (126/182) para 'dados_sociedades'.
#   Extraído '202401Sociedades.zip' (127/182) para 'dados_sociedades'.
#   Extraído '201103Sociedades.zip' (128/182) para 'dados_sociedades'.
#   Extraído '201012Sociedades.zip' (129/182) para 'dados_sociedades'.
#   Extraído '201702Sociedades.zip' (130/182) para 'dados_sociedades'.
#   Extraído '201603Sociedades.zip' (131/182) para 'dados_sociedades'.
#   Extraído '202208Sociedades.zip' (132/182) para 'dados_sociedades'.
#   Extraído '202012Sociedades.zip' (133/182) para 'dados_sociedades'.
#   Extraído '202211Sociedades.zip' (134/182) para 'dados_sociedades'.
#   Extraído '202005Sociedades.zip' (135/182) para 'dados_sociedades'.
#   Extraído '201306Sociedades.zip' (136/182) para 'dados_sociedades'.
#   Extraído '202311Sociedades.zip' (137/182) para 'dados_sociedades'.
#   Extraído '201110Sociedades.zip' (138/182) para 'dados_sociedades'.
#   Extraído '201208Sociedades.zip' (139/182) para 'dados_sociedades'.
#   Extraído '201104Sociedades.zip' (140/182) para 'dados_sociedades'.
#   Extraído '202209Sociedades.zip' (141/182) para 'dados_sociedades'.
#   Extraído '201311Sociedades.zip' (142/182) para 'dados_sociedades'.
#   Extraído '201105Sociedades.zip' (143/182) para 'dados_sociedades'.
#   Extraído '201411Sociedades.zip' (144/182) para 'dados_sociedades'.
#   Extraído '201902Sociedades.zip' (145/182) para 'dados_sociedades'.
#   Extraído '201002Sociedades.zip' (146/182) para 'dados_sociedades'.
#   Extraído '202501Sociedades.zip' (147/182) para 'dados_sociedades'.
#   Extraído '201607Sociedades.zip' (148/182) para 'dados_sociedades'.
#   Extraído '201211Sociedades.zip' (149/182) para 'dados_sociedades'.
#   Extraído '201901Sociedades.zip' (150/182) para 'dados_sociedades'.
#   Extraído '201612Sociedades.zip' (151/182) para 'dados_sociedades'.
#   Extraído '202204Sociedades.zip' (152/182) para 'dados_sociedades'.
#   Extraído '201711Sociedades.zip' (153/182) para 'dados_sociedades'.
#   Extraído '201909Sociedades.zip' (154/182) para 'dados_sociedades'.
#   Extraído '201605Sociedades.zip' (155/182) para 'dados_sociedades'.
#   Extraído '201508Sociedades.zip' (156/182) para 'dados_sociedades'.
#   Extraído '202111Sociedades.zip' (157/182) para 'dados_sociedades'.
#   Extraído '202009Sociedades.zip' (158/182) para 'dados_sociedades'.
#   Extraído '201107Sociedades.zip' (159/182) para 'dados_sociedades'.
#   Extraído '201805Sociedades.zip' (160/182) para 'dados_sociedades'.
#   Extraído '201309Sociedades.zip' (161/182) para 'dados_sociedades'.
#   Extraído '201910Sociedades.zip' (162/182) para 'dados_sociedades'.
#   Extraído '201801Sociedades.zip' (163/182) para 'dados_sociedades'.
#   Extraído '201509Sociedades.zip' (164/182) para 'dados_sociedades'.
#   Extraído '202406Sociedades.zip' (165/182) para 'dados_sociedades'.
#   Extraído '202310Sociedades.zip' (166/182) para 'dados_sociedades'.
#   Extraído '201009Sociedades.zip' (167/182) para 'dados_sociedades'.
#   Extraído '201807Sociedades.zip' (168/182) para 'dados_sociedades'.
#   Extraído '202101Sociedades.zip' (169/182) para 'dados_sociedades'.
#   Extraído '201507Sociedades.zip' (170/182) para 'dados_sociedades'.
#   Extraído '201810Sociedades.zip' (171/182) para 'dados_sociedades'.
#   Extraído '201510Sociedades.zip' (172/182) para 'dados_sociedades'.
#   Extraído '201812Sociedades.zip' (173/182) para 'dados_sociedades'.
#   Extraído '202412Sociedades.zip' (174/182) para 'dados_sociedades'.
#   Extraído '201703Sociedades.zip' (175/182) para 'dados_sociedades'.
#   Extraído '201904Sociedades.zip' (176/182) para 'dados_sociedades'.
#   Extraído '201404Sociedades.zip' (177/182) para 'dados_sociedades'.
#   Extraído '202402Sociedades.zip' (178/182) para 'dados_sociedades'.
#   Extraído '201808Sociedades.zip' (179/182) para 'dados_sociedades'.
#   Extraído '201006Sociedades.zip' (180/182) para 'dados_sociedades'.
#   Extraído '202303Sociedades.zip' (181/182) para 'dados_sociedades'.
#   Extraído '201312Sociedades.zip' (182/182) para 'dados_sociedades'.

# %%
import pandas as pd
import os

def combinar_csvs(
    diretorio_csvs="dados_sociedades",
    nome_arquivo_saida="cosif_sociedades_financeiras.csv",
    diretorio_saida="dados_bcb_cosif_combinados"
):
    """
    Combina todos os arquivos CSV de um diretório em um único arquivo CSV.

    Args:
        diretorio_csvs (str): O caminho para o diretório onde os arquivos CSV estão.
        nome_arquivo_saida (str): O nome do arquivo CSV de saída combinado.
        diretorio_saida (str): O diretório onde o arquivo combinado será salvo.
    """
    print(f"Iniciando a combinação dos arquivos CSV de: {diretorio_csvs}")

    # Cria o diretório de saída para o arquivo combinado, se não existir
    if not os.path.exists(diretorio_saida):
        os.makedirs(diretorio_saida)
        print(f"Diretório '{diretorio_saida}' criado para o arquivo combinado.")
    else:
        print(f"Diretório '{diretorio_saida}' já existe.")

    # Lista todos os arquivos no diretório de CSVs
    arquivos_no_diretorio = os.listdir(diretorio_csvs)
    csv_encontrados = [f for f in arquivos_no_diretorio if f.endswith('.CSV')]

    if not csv_encontrados:
        print(f"Nenhum arquivo CSV encontrado no diretório '{diretorio_csvs}'.")
        return

    print(f"Encontrados {len(csv_encontrados)} arquivos CSV para combinar.")

    lista_dataframes = []

    for i, nome_csv in enumerate(csv_encontrados):
        caminho_completo_csv = os.path.join(diretorio_csvs, nome_csv)
        
        try:

            df = pd.read_csv(
                caminho_completo_csv,
                sep=';',              # Separador de colunas é ponto e vírgula
                encoding='latin1',    # Codificação de caracteres comum para o português
                skiprows=4,           # Pula as 4 primeiras linhas de metadados
                decimal=',',          # Usa vírgula como separador decimal para números
                on_bad_lines='warn'   # Avisa sobre linhas problemáticas, mas tenta continuar
            )

            lista_dataframes.append(df)
            print(f"  Lido '{nome_csv}' ({i+1}/{len(csv_encontrados)})")
        except FileNotFoundError:
            print(f"  Erro: Arquivo '{nome_csv}' não encontrado. Pulando.")
        except pd.errors.EmptyDataError:
            print(f"  Aviso: Arquivo '{nome_csv}' está vazio. Pulando.")
        except Exception as e:
            print(f"  Erro inesperado ao ler '{nome_csv}': {e}. Pulando.")

    if not lista_dataframes:
        print("Nenhum DataFrame válido para combinar.")
        return

    # Concatena todos os DataFrames na lista em um único DataFrame
    print("\nCombinando todos os DataFrames...")
    df_combinado = pd.concat(lista_dataframes, ignore_index=True)

    # Caminho completo para o arquivo de saída
    caminho_saida_completo = os.path.join(diretorio_saida, nome_arquivo_saida)

    # Salva o DataFrame combinado em um novo arquivo CSV
    # Você pode escolher o separador e o encoding para o arquivo de saída também.
    df_combinado.to_csv(caminho_saida_completo, sep=';', encoding='latin1', index=False)
    print(f"\nTodos os CSVs foram combinados em: '{caminho_saida_completo}'")

# --- Configurações de Combinação ---
# O diretório onde os arquivos CSV foram extraídos (o mesmo usado no script de extração)
DIRETORIO_DOS_CSVS_EXTRAIDOS = "dados_sociedades"

# O nome do arquivo CSV final combinado
NOME_ARQUIVO_CSV_FINAL = "cosif_sociedades_financeiras.csv"

# O diretório onde o arquivo combinado será salvo
DIRETORIO_ONDE_SALVAR_COMBINADO = "dados_bcb_cosif_combinados"

# Chama a função para iniciar a combinação
combinar_csvs(
    diretorio_csvs=DIRETORIO_DOS_CSVS_EXTRAIDOS,
    nome_arquivo_saida=NOME_ARQUIVO_CSV_FINAL,
    diretorio_saida=DIRETORIO_ONDE_SALVAR_COMBINADO
)
# Out:
# Iniciando a combinação dos arquivos CSV de: dados_sociedades
# Diretório 'dados_bcb_cosif_combinados' já existe.
# Encontrados 181 arquivos CSV para combinar.
#   Lido '201305SOCIEDADES.CSV' (1/181)
#   Lido '202207SOCIEDADES.CSV' (2/181)
#   Lido '201801SOCIEDADES.CSV' (3/181)
#   Lido '201212SOCIEDADES.CSV' (4/181)
#   Lido '201311SOCIEDADES.CSV' (5/181)
#   Lido '201104SOCIEDADES.CSV' (6/181)
#   Lido '201702SOCIEDADES.CSV' (7/181)
#   Lido '202307SOCIEDADES.CSV' (8/181)
#   Lido '202206SOCIEDADES.CSV' (9/181)
#   Lido '201902SOCIEDADES.CSV' (10/181)
#   Lido '202407SOCIEDADES.CSV' (11/181)
#   Lido '201510SOCIEDADES.CSV' (12/181)
#   Lido '201101SOCIEDADES.CSV' (13/181)
#   Lido '201608SOCIEDADES.CSV' (14/181)
#   Lido '202010SOCIEDADES.CSV' (15/181)
#   Lido '201606SOCIEDADES.CSV' (16/181)
#   Lido '202201SOCIEDADES.CSV' (17/181)
#   Lido '202101SOCIEDADES.CSV' (18/181)
#   Lido '202412SOCIEDADES.CSV' (19/181)
#   Lido '202103SOCIEDADES.CSV' (20/181)
#   Lido '201602SOCIEDADES.CSV' (21/181)
#   Lido '201603SOCIEDADES.CSV' (22/181)
#   Lido '201407SOCIEDADES.CSV' (23/181)
#   Lido '201108SOCIEDADES.CSV' (24/181)
#   Lido '202009SOCIEDADES.CSV' (25/181)
#   Lido '201001SOCIEDADES.CSV' (26/181)
#   Lido '201209SOCIEDADES.CSV' (27/181)
#   Lido '201502SOCIEDADES.CSV' (28/181)
#   Lido '201102SOCIEDADES.CSV' (29/181)
#   Lido '201903SOCIEDADES.CSV' (30/181)
#   Lido '202312SOCIEDADES.CSV' (31/181)
#   Lido '201712SOCIEDADES.CSV' (32/181)
#   Lido '201103SOCIEDADES.CSV' (33/181)
#   Lido '201208SOCIEDADES.CSV' (34/181)
#   Lido '201809SOCIEDADES.CSV' (35/181)
#   Lido '201204SOCIEDADES.CSV' (36/181)
#   Lido '201304SOCIEDADES.CSV' (37/181)
#   Lido '201405SOCIEDADES.CSV' (38/181)
#   Lido '201401SOCIEDADES.CSV' (39/181)
#   Lido '202410SOCIEDADES.CSV' (40/181)
#   Lido '201701SOCIEDADES.CSV' (41/181)
#   Lido '201110SOCIEDADES.CSV' (42/181)
#   Lido '202106SOCIEDADES.CSV' (43/181)
#   Lido '202310SOCIEDADES.CSV' (44/181)
#   Lido '201811SOCIEDADES.CSV' (45/181)
#   Lido '201211SOCIEDADES.CSV' (46/181)
#   Lido '202205SOCIEDADES.CSV' (47/181)
#   Lido '202208SOCIEDADES.CSV' (48/181)
#   Lido '201912SOCIEDADES.CSV' (49/181)
#   Lido '201301SOCIEDADES.CSV' (50/181)
#   Lido '201306SOCIEDADES.CSV' (51/181)
#   Lido '201402SOCIEDADES.CSV' (52/181)
#   Lido '201609SOCIEDADES.CSV' (53/181)
#   Lido '202112SOCIEDADES.CSV' (54/181)
#   Lido '201404SOCIEDADES.CSV' (55/181)
#   Lido '202402SOCIEDADES.CSV' (56/181)
#   Lido '202204SOCIEDADES.CSV' (57/181)
#   Lido '201908SOCIEDADES.CSV' (58/181)
#   Lido '201308SOCIEDADES.CSV' (59/181)
#   Lido '201905SOCIEDADES.CSV' (60/181)
#   Lido '201501SOCIEDADES.CSV' (61/181)
#   Lido '201508SOCIEDADES.CSV' (62/181)
#   Lido '202109SOCIEDADES.CSV' (63/181)
#   Lido '202405SOCIEDADES.CSV' (64/181)
#   Lido '201711SOCIEDADES.CSV' (65/181)
#   Lido '201910SOCIEDADES.CSV' (66/181)
#   Lido '202308SOCIEDADES.CSV' (67/181)
#   Lido '202005SOCIEDADES.CSV' (68/181)
#   Lido '201312SOCIEDADES.CSV' (69/181)
#   Lido '202004SOCIEDADES.CSV' (70/181)
#   Lido '202502SOCIEDADES.CSV' (71/181)
#   Lido '202305SOCIEDADES.CSV' (72/181)
#   Lido '201207SOCIEDADES.CSV' (73/181)
#   Lido '201804SOCIEDADES.CSV' (74/181)
#   Lido '202002SOCIEDADES.CSV' (75/181)
#   Lido '201007SOCIEDADES.CSV' (76/181)
#   Lido '201202SOCIEDADES.CSV' (77/181)
#   Lido '202012SOCIEDADES.CSV' (78/181)
#   Lido '201106SOCIEDADES.CSV' (79/181)
#   Lido '202111SOCIEDADES.CSV' (80/181)
#   Lido '202203SOCIEDADES.CSV' (81/181)
#   Lido '201411SOCIEDADES.CSV' (82/181)
#   Lido '201512SOCIEDADES.CSV' (83/181)
#   Lido '201706SOCIEDADES.CSV' (84/181)
#   Lido '201503SOCIEDADES.CSV' (85/181)
#   Lido '201107SOCIEDADES.CSV' (86/181)
#   Lido '201704SOCIEDADES.CSV' (87/181)
#   Lido '201710SOCIEDADES.CSV' (88/181)
#   Lido '201004SOCIEDADES.CSV' (89/181)
#   Lido '201409SOCIEDADES.CSV' (90/181)
#   Lido '201803SOCIEDADES.CSV' (91/181)
#   Lido '201012SOCIEDADES.CSV' (92/181)
#   Lido '202311SOCIEDADES.CSV' (93/181)
#   Lido '201705SOCIEDADES.CSV' (94/181)
#   Lido '201206SOCIEDADES.CSV' (95/181)
#   Lido '202210SOCIEDADES.CSV' (96/181)
#   Lido '201009SOCIEDADES.CSV' (97/181)
#   Lido '202001SOCIEDADES.CSV' (98/181)
#   Lido '201408SOCIEDADES.CSV' (99/181)
#   Lido '202309SOCIEDADES.CSV' (100/181)
#   Lido '201005SOCIEDADES.CSV' (101/181)
#   Lido '201904SOCIEDADES.CSV' (102/181)
#   Lido '201002SOCIEDADES.CSV' (103/181)
#   Lido '201808SOCIEDADES.CSV' (104/181)
#   Lido '202007SOCIEDADES.CSV' (105/181)
#   Lido '201708SOCIEDADES.CSV' (106/181)
#   Lido '202409SOCIEDADES.CSV' (107/181)
#   Lido '201504SOCIEDADES.CSV' (108/181)
#   Lido '201111SOCIEDADES.CSV' (109/181)
#   Lido '202110SOCIEDADES.CSV' (110/181)
#   Lido '201605SOCIEDADES.CSV' (111/181)
#   Lido '201901SOCIEDADES.CSV' (112/181)
#   Lido '202401SOCIEDADES.CSV' (113/181)
#   Lido '202202SOCIEDADES.CSV' (114/181)
#   Lido '202102SOCIEDADES.CSV' (115/181)
#   Lido '201709SOCIEDADES.CSV' (116/181)
#   Lido '202404SOCIEDADES.CSV' (117/181)
#   Lido '201105SOCIEDADES.CSV' (118/181)
#   Lido '201601SOCIEDADES.CSV' (119/181)
#   Lido '201703SOCIEDADES.CSV' (120/181)
#   Lido '202306SOCIEDADES.CSV' (121/181)
#   Lido '201307SOCIEDADES.CSV' (122/181)
#   Lido '201911SOCIEDADES.CSV' (123/181)
#   Lido '202105SOCIEDADES.CSV' (124/181)
#   Lido '201611SOCIEDADES.CSV' (125/181)
#   Lido '201008SOCIEDADES.CSV' (126/181)
#   Lido '201707SOCIEDADES.CSV' (127/181)
#   Lido '201812SOCIEDADES.CSV' (128/181)
#   Lido '201607SOCIEDADES.CSV' (129/181)
#   Lido '201006SOCIEDADES.CSV' (130/181)
#   Lido '201201SOCIEDADES.CSV' (131/181)
#   Lido '201505SOCIEDADES.CSV' (132/181)
#   Lido '202011SOCIEDADES.CSV' (133/181)
#   Lido '201907SOCIEDADES.CSV' (134/181)
#   Lido '201805SOCIEDADES.CSV' (135/181)
#   Lido '201604SOCIEDADES.CSV' (136/181)
#   Lido '202408SOCIEDADES.CSV' (137/181)
#   Lido '201906SOCIEDADES.CSV' (138/181)
#   Lido '201205SOCIEDADES.CSV' (139/181)
#   Lido '201509SOCIEDADES.CSV' (140/181)
#   Lido '202008SOCIEDADES.CSV' (141/181)
#   Lido '201807SOCIEDADES.CSV' (142/181)
#   Lido '202108SOCIEDADES.CSV' (143/181)
#   Lido '201506SOCIEDADES.CSV' (144/181)
#   Lido '202003SOCIEDADES.CSV' (145/181)
#   Lido '201403SOCIEDADES.CSV' (146/181)
#   Lido '202006SOCIEDADES.CSV' (147/181)
#   Lido '202411SOCIEDADES.CSV' (148/181)
#   Lido '201210SOCIEDADES.CSV' (149/181)
#   Lido '202104SOCIEDADES.CSV' (150/181)
#   Lido '202501SOCIEDADES.CSV' (151/181)
#   Lido '201109SOCIEDADES.CSV' (152/181)
#   Lido '202107SOCIEDADES.CSV' (153/181)
#   Lido '202302SOCIEDADES.CSV' (154/181)
#   Lido '202303SOCIEDADES.CSV' (155/181)
#   Lido '201203SOCIEDADES.CSV' (156/181)
#   Lido '202403SOCIEDADES.CSV' (157/181)
#   Lido '201511SOCIEDADES.CSV' (158/181)
#   Lido '201610SOCIEDADES.CSV' (159/181)
#   Lido '201802SOCIEDADES.CSV' (160/181)
#   Lido '202503SOCIEDADES.CSV' (161/181)
#   Lido '201410SOCIEDADES.CSV' (162/181)
#   Lido '201909SOCIEDADES.CSV' (163/181)
#   Lido '202211SOCIEDADES.CSV' (164/181)
#   Lido '201010SOCIEDADES.CSV' (165/181)
#   Lido '201806SOCIEDADES.CSV' (166/181)
#   Lido '201309SOCIEDADES.CSV' (167/181)
#   Lido '201612SOCIEDADES.CSV' (168/181)
#   Lido '201507SOCIEDADES.CSV' (169/181)
#   Lido '201112SOCIEDADES.CSV' (170/181)
#   Lido '202209SOCIEDADES.CSV' (171/181)
#   Lido '201303SOCIEDADES.CSV' (172/181)
#   Lido '201302SOCIEDADES.CSV' (173/181)
#   Lido '201003SOCIEDADES.CSV' (174/181)
#   Lido '202406SOCIEDADES.CSV' (175/181)
#   Lido '201406SOCIEDADES.CSV' (176/181)
#   Lido '201810SOCIEDADES.CSV' (177/181)
#   Lido '201011SOCIEDADES.CSV' (178/181)
#   Lido '202304SOCIEDADES.CSV' (179/181)
#   Lido '201310SOCIEDADES.CSV' (180/181)
#   Lido '201412SOCIEDADES.CSV' (181/181)
#
# Combinando todos os DataFrames...
